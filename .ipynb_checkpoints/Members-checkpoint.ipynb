# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
members = Member.objects.all()

# %%
members_data = pd.DataFrame(list(members.values()))

# %%
members_data = members_data.sort_values(by=['priority', 'create_at'], ascending=[False, True])

# %%
members_data
# Out:
#    id                               session  queue_id  priority create_at
# 2  13  e7b1d53b-1d8a-458e-8e7b-7e29cf58e310         4      True  19:03:50
# 3  14  5108e6d6-1487-4036-bcf2-ade40f153c9d         4      True  19:03:53
# 4  15  ed48de94-e21b-4ea9-8f93-29e12d7bee65         4      True  19:03:56
# 8  19  3679847d-f1fe-4258-9c16-8ae8166c9bf7         4     False  16:22:35
# 0  11  d4f2c348-7fde-42af-97c5-33c01d38a6d8         4     False  19:03:44
# 1  12  4cc97d03-9547-4b12-8b3d-d3ad5862f42b         4     False  19:03:48
# 5  16  0e6792c2-c72d-4c24-b793-89975ae8539f         4     False  19:03:59
# 6  17  8168b070-bd23-4785-a26f-293192522ef9         4     False  19:04:01
# 7  18  73556e9e-da37-4b0c-ae4b-3889a18f8cb3         4     False  19:04:04

# %%
members_data.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="640">
